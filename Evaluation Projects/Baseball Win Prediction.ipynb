# %% [markdown]
# This dataset contains 30 rows and 17 columns

# %% [markdown]
# # Renaming the Columns

# %%
df.columns = ['Wins' , 'Runs', 'At_Bats', 'Hits', 'Double', 'Triple', 'Home_runs', 'Walk', 'Strikeouts', 'Stolen_Bases', 'Runs_Average', 'Earned_Runs','Earned_Run_Average', 'Complete_Games','Shutouts', 'Saves','Errors']

# %%
df.head(5)
# Out:
#    Wins  Runs  At_Bats  Hits  Double  Triple  Home_runs  Walk  Strikeouts  \
# 0    95   724     5575  1497     300      42        139   383         973
# 1    83   696     5467  1349     277      44        156   439        1264
# 2    81   669     5439  1395     303      29        141   533        1157
# 3    76   622     5533  1381     260      27        136   404        1231
# 4    74   689     5605  1515     289      49        151   455        1259
#
#    Stolen_Bases  Runs_Average  Earned_Runs  Earned_Run_Average  \
# 0           104           641          601                3.73
# 1            70           700          653                4.07
# 2            86           640          584                3.67
# 3            68           701          643                3.98
# 4            83           803          746                4.64
#
#    Complete_Games  Shutouts  Saves  Errors
# 0               2         8     56      88
# 1               2        12     45      86
# 2              11        10     38      79
# 3               7         9     37     101
# 4               7        12     35      86

# %%
df.tail(5)
# Out:
#     Wins  Runs  At_Bats  Hits  Double  Triple  Home_runs  Walk  Strikeouts  \
# 25    92   667     5385  1346     263      26        187   563        1258
# 26    84   696     5565  1486     288      39        136   457        1159
# 27    79   720     5649  1494     289      48        154   490        1312
# 28    74   650     5457  1324     260      36        148   426        1327
# 29    68   737     5572  1479     274      49        186   388        1283
#
#     Stolen_Bases  Runs_Average  Earned_Runs  Earned_Run_Average  \
# 25            59           595          553                3.44
# 26            93           627          597                3.72
# 27           132           713          659                4.04
# 28            82           731          655                4.09
# 29            97           844          799                5.04
#
#     Complete_Games  Shutouts  Saves  Errors
# 25               6        21     47      75
# 26               7        18     41      78
# 27               1        12     44      86
# 28               1         6     41      92
# 29               4         4     36      95

# %%
# To see columns in a list
df.columns.tolist()
# Out:
# ['Wins',
#  'Runs',
#  'At_Bats',
#  'Hits',
#  'Double',
#  'Triple',
#  'Home_runs',
#  'Walk',
#  'Strikeouts',
#  'Stolen_Bases',
#  'Runs_Average',
#  'Earned_Runs',
#  'Earned_Run_Average',
#  'Complete_Games',
#  'Shutouts',
#  'Saves',
#  'Errors']

# %%
#Checking the datatypes of all columns
df.dtypes
# Out:
# Wins                    int64
# Runs                    int64
# At_Bats                 int64
# Hits                    int64
# Double                  int64
# Triple                  int64
# Home_runs               int64
# Walk                    int64
# Strikeouts              int64
# Stolen_Bases            int64
# Runs_Average            int64
# Earned_Runs             int64
# Earned_Run_Average    float64
# Complete_Games          int64
# Shutouts                int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %% [markdown]
# Here we can see that all are numerical columns. Only one is float datatype all others are integers.

# %% [markdown]
# # Checking Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs                30 non-null     int64
#  2   At_Bats             30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Double              30 non-null     int64
#  5   Triple              30 non-null     int64
#  6   Home_runs           30 non-null     int64
#  7   Walk                30 non-null     int64
#  8   Strikeouts          30 non-null     int64
#  9   Stolen_Bases        30 non-null     int64
#  10  Runs_Average        30 non-null     int64
#  11  Earned_Runs         30 non-null     int64
#  12  Earned_Run_Average  30 non-null     float64
#  13  Complete_Games      30 non-null     int64
#  14  Shutouts            30 non-null     int64
#  15  Saves               30 non-null     int64
#  16  Errors              30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# Lets see using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Here we can see that no null/missing values in this dataset.

# %% [markdown]
# # Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Wins, Runs, At_Bats, Hits, Double, Triple, Home_runs, Walk, Strikeouts, Stolen_Bases, Runs_Average, Earned_Runs, Earned_Run_Average, Complete_Games, Shutouts, Saves, Errors]
# Index: []

# %% [markdown]
# No duplicates found

# %%
#statisdical summary of numerical columns
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits      Double  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#           Triple   Home_runs        Walk  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs_Average  Earned_Runs  Earned_Run_Average  Complete_Games  \
# count     30.000000    30.000000           30.000000       30.000000
# mean     688.233333   635.833333            3.956333        3.466667
# std       72.108005    70.140786            0.454089        2.763473
# min      525.000000   478.000000            2.940000        0.000000
# 25%      636.250000   587.250000            3.682500        1.000000
# 50%      695.500000   644.500000            4.025000        3.000000
# 75%      732.500000   679.250000            4.220000        5.750000
# max      844.000000   799.000000            5.040000       11.000000
#
#         Shutouts      Saves      Errors
# count  30.000000  30.000000   30.000000
# mean   11.300000  43.066667   94.333333
# std     4.120177   7.869335   13.958889
# min     4.000000  28.000000   75.000000
# 25%     9.000000  37.250000   86.000000
# 50%    12.000000  42.000000   91.000000
# 75%    13.000000  46.750000   96.750000
# max    21.000000  62.000000  126.000000

# %% [markdown]
# From the above, we can see that
#
# 1) The dataset looks perfect because it did not have any negative/invalid datas
# 2) The counts are same, so no missing values
# 3) The mean and median are not equal, so skewness is present.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariant Analysis

# %%
for i in df :
    sns.distplot(df[i] , kde = True , color = 'red' )
    plt.xlabel(i)
    plt.ylabel("count")
    plt.title(i)
    plt.show()

# %%
for i in df :
    sns.violinplot(df[i] , kde = True , color = 'blue' )
    plt.xlabel(i)
    plt.ylabel("count")
    plt.title(i)
    plt.show()

# %%
plot = df.plot(kind='kde', subplots=True, layout=(9,2), figsize=(10,10))
plot
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# Bi Variant Analysis

# %%
for i in df.columns :
    sns.lmplot(x=i, y='Wins', data =df)
    plt.xlabel(i)
    plt.ylabel("Wins")
    plt.title(i)
    plt.show()

# %% [markdown]
# From the above obsevation, we can see that,
#
# 1) 'Runs', 'Double', 'Home_runs', 'Walk', 'Shutouts', 'Saves' are directly propotional to 'Wins'
#
# 2) 'Earned_Run_Average', 'Earned_Runs', 'Runs_Average' are inversely propotional to 'Wins'

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                         Wins      Runs   At_Bats      Hits    Double  \
# Wins                1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                0.430751  1.000000  0.319464  0.482856  0.560084
# At_Bats            -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                0.037612  0.482856  0.739122  1.000000  0.566847
# Double              0.427797  0.560084  0.453370  0.566847  1.000000
# Triple             -0.251118 -0.070072  0.435422  0.478694  0.220490
# Home_runs           0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walk                0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts          0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen_Bases       -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs_Average       -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned_Runs        -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned_Run_Average -0.819600 -0.049281  0.255551  0.231172 -0.254854
# Complete_Games      0.080533  0.232042 -0.080876  0.147955  0.306675
# Shutouts            0.471805 -0.103274 -0.197321 -0.145559  0.057998
# Saves               0.666530 -0.096380 -0.106367 -0.130371  0.171576
# Errors             -0.089485 -0.023262  0.316743 -0.033173  0.105754
#
#                       Triple  Home_runs      Walk  Strikeouts  Stolen_Bases  \
# Wins               -0.251118   0.307407  0.484342    0.111850     -0.157234
# Runs               -0.070072   0.671283  0.402452   -0.054726      0.081367
# At_Bats             0.435422  -0.066983 -0.136414   -0.106022      0.372618
# Hits                0.478694  -0.090855 -0.118281   -0.398830      0.413444
# Double              0.220490   0.056292  0.302700   -0.150752      0.195027
# Triple              1.000000  -0.430915 -0.454949   -0.141196      0.457437
# Home_runs          -0.430915   1.000000  0.425691    0.359923     -0.136567
# Walk               -0.454949   0.425691  1.000000    0.233652     -0.098347
# Strikeouts         -0.141196   0.359923  0.233652    1.000000      0.030968
# Stolen_Bases        0.457437  -0.136567 -0.098347    0.030968      1.000000
# Runs_Average        0.314125  -0.103903 -0.416445   -0.129745      0.132290
# Earned_Runs         0.340225  -0.085922 -0.452663   -0.161612      0.143068
# Earned_Run_Average  0.330951  -0.090917 -0.459832   -0.180368      0.126063
# Complete_Games     -0.065898   0.156502  0.462478   -0.093418     -0.020783
# Shutouts           -0.041396  -0.019119  0.426004    0.237721     -0.106563
# Saves              -0.142370  -0.028540  0.099445    0.126297     -0.183418
# Errors              0.126678  -0.207597 -0.075685    0.155133      0.079149
#
#                     Runs_Average  Earned_Runs  Earned_Run_Average  \
# Wins                   -0.812952    -0.809435           -0.819600
# Runs                   -0.041623    -0.041245           -0.049281
# At_Bats                 0.316010     0.309686            0.255551
# Hits                    0.224324     0.252489            0.231172
# Double                 -0.218160    -0.235531           -0.254854
# Triple                  0.314125     0.340225            0.330951
# Home_runs              -0.103903    -0.085922           -0.090917
# Walk                   -0.416445    -0.452663           -0.459832
# Strikeouts             -0.129745    -0.161612           -0.180368
# Stolen_Bases            0.132290     0.143068            0.126063
# Runs_Average            1.000000     0.991018            0.986674
# Earned_Runs             0.991018     1.000000            0.997248
# Earned_Run_Average      0.986674     0.997248            1.000000
# Complete_Games         -0.016659    -0.020221           -0.009856
# Shutouts               -0.636862    -0.630192           -0.630833
# Saves                  -0.616224    -0.589663           -0.607005
# Errors                  0.198996     0.136921            0.113137
#
#                     Complete_Games  Shutouts     Saves    Errors
# Wins                      0.080533  0.471805  0.666530 -0.089485
# Runs                      0.232042 -0.103274 -0.096380 -0.023262
# At_Bats                  -0.080876 -0.197321 -0.106367  0.316743
# Hits                      0.147955 -0.145559 -0.130371 -0.033173
# Double                    0.306675  0.057998  0.171576  0.105754
# Triple                   -0.065898 -0.041396 -0.142370  0.126678
# Home_runs                 0.156502 -0.019119 -0.028540 -0.207597
# Walk                      0.462478  0.426004  0.099445 -0.075685
# Strikeouts               -0.093418  0.237721  0.126297  0.155133
# Stolen_Bases             -0.020783 -0.106563 -0.183418  0.079149
# Runs_Average             -0.016659 -0.636862 -0.616224  0.198996
# Earned_Runs              -0.020221 -0.630192 -0.589663  0.136921
# Earned_Run_Average       -0.009856 -0.630833 -0.607005  0.113137
# Complete_Games            1.000000  0.241676 -0.367766 -0.140047
# Shutouts                  0.241676  1.000000  0.221639 -0.115716
# Saves                    -0.367766  0.221639  1.000000 -0.025636
# Errors                   -0.140047 -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(),cmap='Reds',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# From the above, we can see that
#
# 1) The features 'Earned_Run_Average', 'Earned_Runs'and  'Runs_Average' has very high correlation with each other.
# 2) The features 'At_Bats' and  'Hits' has high correlation with each other.
# 3) The target variable 'Wins' has positive correlation with features 'Runs', 'Double', 'Home_runs', 'Walk', 'Shutouts'and 'Saves'.
# 4) The target variable 'Wins' has very high negative correlation with features 'Earned_Run_Average', 'Earned_Runs' and 'Runs_Average'.

# %% [markdown]
# # Checking for Outliers

# %%
plot = df.plot(kind='box', subplots=True, layout=(9,2), figsize=(20,20))
plot
# Out:
# Wins                     Axes(0.125,0.807358;0.352273x0.0726415)
# Runs                  Axes(0.547727,0.807358;0.352273x0.0726415)
# At_Bats                  Axes(0.125,0.720189;0.352273x0.0726415)
# Hits                  Axes(0.547727,0.720189;0.352273x0.0726415)
# 18            0.724968        0.907856  1.061486  0.396360  1.578712
# 19            0.836961        0.539806  0.814629  1.042600  0.315742
# 20            1.178913        0.907856  0.666514  0.896119  0.461470
# 21            0.753340        0.196293  0.419657  0.267112  0.315742
# 22            0.142604        1.275906  0.172800  1.042600  1.262970
# 23            1.016150        0.171757  0.320914  0.120631  0.315742
# 24            1.643311        0.907856  1.061486  1.042600  1.651576
# 25            1.156515        0.932393  2.394514  0.508375  1.408697
# 26            0.529354        1.300442  1.653943  0.267112  1.190106
# 27            0.187402        0.907856  0.172800  0.120631  0.607197
# 28            0.299395        0.907856  1.308343  0.267112  0.170015
# 29            2.427263        0.196293  1.802057  0.913352  0.048576

# %%
# threshold =3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z.iloc[5,1]
# Out:
# 3.5096470447193067

# %% [markdown]
# Only one outlier present, we will ignore that.

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# Wins                  0.047089
# Runs                  1.200786
# At_Bats               0.183437
# Hits                  0.670254
# Double               -0.230650
# Triple                0.129502
# Home_runs             0.516441
# Walk                  0.158498
# Strikeouts           -0.156065
# Stolen_Bases          0.479893
# Runs_Average          0.045734
# Earned_Runs           0.058710
# Earned_Run_Average    0.053331
# Complete_Games        0.736845
# Shutouts              0.565790
# Saves                 0.657524
# Errors                0.890132
# dtype: float64

# %% [markdown]
# # Removing Skewness

# %%
df['Runs'] = np.cbrt(df['Runs'])
df['Complete_Games'] = np.cbrt(df['Complete_Games'])
df['Saves'] = np.cbrt(df['Saves'])
df['Errors'] = np.cbrt(df['Errors'])

# %%
df.skew()
# Out:
# Wins                  0.047089
# Runs                  0.892970
# At_Bats               0.183437
# Hits                  0.670254
# Double               -0.230650
# Triple                0.129502
# Home_runs             0.516441
# Walk                  0.158498
# Strikeouts           -0.156065
# Stolen_Bases          0.479893
# Runs_Average          0.045734
# Earned_Runs           0.058710
# Earned_Run_Average    0.053331
# Complete_Games       -1.043632
# Shutouts              0.565790
# Saves                 0.325143
# Errors                0.719735
# dtype: float64

# %% [markdown]
# # Splitting target variable

# %%
x = df.drop("Wins", axis = 1)
y= df['Wins']

# %%
x
# Out:
#         Runs  At_Bats  Hits  Double  Triple  Home_runs  Walk  Strikeouts  \
# 0   8.979377     5575  1497     300      42        139   383         973
# 1   8.862095     5467  1349     277      44        156   439        1264
# 2   8.745985     5439  1395     303      29        141   533        1157
# 3   8.536178     5533  1381     260      27        136   404        1231
# 4   8.832285     5605  1515     289      49        151   455        1259
# 5   9.622603     5509  1480     308      17        232   570        1151
# 6   9.141787     5567  1397     272      19        212   554        1227
# 7   8.933669     5485  1370     246      20        217   418        1331
# 8   8.635655     5485  1383     278      32        167   436        1310
# 9   9.077520     5640  1495     294      33        161   478        1148
# 10  9.089639     5511  1419     279      32        172   503        1233
# 11  9.000000     5459  1363     278      26        230   486        1392
# 12  8.710983     5417  1331     243      21        176   435        1150
# 13  8.688963     5544  1379     262      22        198   478        1336
# 14  8.853599     5600  1405     277      46        146   475        1119
# 15  8.649044     5484  1386     288      39        137   506        1267
# 16  8.866338     5631  1462     292      27        140   461        1322
# 17  8.832285     5491  1341     272      30        171   567        1518
# 18  8.684546     5480  1378     274      34        145   412        1299
# 19  8.617739     5571  1382     257      27        167   496        1255
# 20  8.806572     5527  1351     295      17        177   488        1290
# 21  8.891706     5428  1363     265      13        177   539        1344
# 22  8.494807     5463  1420     236      40        120   375        1150
# 23  8.305865     5420  1361     251      18        100   471        1107
# 24  8.554437     5529  1374     272      37        130   387        1274
# 25  8.737260     5385  1346     263      26        187   563        1258
# 26  8.862095     5565  1486     288      39        136   457        1159
# 27  8.962809     5649  1494     289      48        154   490        1312
# 28  8.662391     5457  1324     260      36        148   426        1327
# 29  9.032802     5572  1479     274      49        186   388        1283
#
#     Stolen_Bases  Runs_Average  Earned_Runs  Earned_Run_Average  \
# 0            104           641          601                3.73
# 1             70           700          653                4.07
# 2             86           640          584                3.67
# 3             68           701          643                3.98
# 4             83           803          746                4.64
# 5             88           670          609                3.80
# 6             63           698          652                4.03
# 7             44           693          646                4.05
# 8             87           642          604                3.74
# 9             71           753          694                4.31
# 10           101           733          680                4.24
# 11           121           618          572                3.57
# 12            52           675          630                3.94
# 13            69           726          677                4.16
# 14            78           729          664                4.14
# 15            69           525          478                2.94
# 16            98           596          532                3.21
# 17            95           608          546                3.36
# 18            84           737          682                4.28
# 19           134           754          700                4.33
# 20            51           613          557                3.43
# 21            57           635          577                3.62
# 22           112           678          638                4.02
# 23            69           760          698                4.41
# 24            88           809          749                4.69
# 25            59           595          553                3.44
# 26            93           627          597                3.72
# 27           132           713          659                4.04
# 28            82           731          655                4.09
# 29            97           844          799                5.04
#
#     Complete_Games  Shutouts     Saves    Errors
# 0         1.259921         8  3.825862  4.447960
# 1         1.259921        12  3.556893  4.414005
# 2         2.223980        10  3.361975  4.290840
# 3         1.912931         9  3.332222  4.657010
# 4         1.912931        12  3.271066  4.414005
# 5         1.912931        10  3.239612  4.447960
# 6         1.442250         4  3.634241  4.530655
# 7         0.000000        10  3.503398  4.254321
# 8         1.000000        12  3.914868  4.562903
# 9         1.442250        10  3.419952  4.594701
# 10        1.709976         9  3.556893  4.918685
# 11        1.709976        13  3.391211  4.396830
# 12        1.259921        12  3.583048  4.530655
# 13        1.817121        12  3.556893  4.546836
# 14        1.709976        15  3.036589  5.013298
# 15        1.000000        15  3.957892  4.578857
# 16        0.000000        13  3.779763  4.959676
# 17        1.817121        21  3.634241  4.805896
# 18        1.000000         7  3.419952  4.876999
# 19        1.259921         8  3.271066  4.481405
# 20        1.000000        14  3.684031  4.447960
# 21        1.587401        13  3.448217  4.481405
# 22        0.000000        12  3.271066  4.254321
# 23        1.442250        10  3.530348  4.481405
# 24        1.000000         7  3.271066  4.890973
# 25        1.817121        21  3.608826  4.217163
# 26        1.912931        18  3.448217  4.272659
# 27        1.000000        12  3.530348  4.414005
# 28        1.000000         6  3.448217  4.514357
# 29        1.587401         4  3.301927  4.562903

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %% [markdown]
# # To remove biasness, we use Standard scaler method

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns
# 22       -2.361588  0.172800 -1.075974 -1.343444
# 23        0.193025 -0.320914  0.181089 -0.283055
# 24       -0.590319 -1.061486 -1.075974  1.629461
# 25        0.857022  2.394514  0.561569 -1.516954
# 26        1.026728  1.653943 -0.217102 -1.257814
# 27       -0.590319  0.172800  0.181089 -0.597785
# 28       -0.590319 -1.308343 -0.217102 -0.129180
# 29        0.450127 -1.802057 -0.926352  0.097506

# %% [markdown]
# # Checking for multicollineraity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["features"] = x.columns

vif
# Out:
#      VIF values            features
# 0     10.925203                Runs
# 1     11.956499             At_Bats
# 2      8.377586                Hits
# 3      4.259061              Double
# 4      3.392650              Triple
# 5     10.377842           Home_runs
# 6      4.004761                Walk
# 7      2.780432          Strikeouts
# 8      1.961694        Stolen_Bases
# 9    192.453953        Runs_Average
# 10  1686.830873         Earned_Runs
# 11  1210.553052  Earned_Run_Average
# 12     2.720680      Complete_Games
# 13     3.627216            Shutouts
# 14     4.292811               Saves
# 15     2.139353              Errors

# %% [markdown]
# By checking VIF values we can see that there is high collineraity between 'Runs_Average', 'Earned_Runs' and 'Earned_Run_Average'.

# %% [markdown]
# We will drop columns 'Runs_Average' and  'Earned_Runs' which has less impact with our target variable compared to'Earned_Run_Average'.

# %%
x.drop(['Earned_Runs'], axis=1, inplace=True)
x.drop(['Runs_Average'], axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["features"] = x.columns

vif
# Out:
#     VIF values            features
# 0     9.901007                Runs
# 1     3.869841             At_Bats
# 2     7.592901                Hits
# 3     3.981264              Double
# 4     3.237913              Triple
# 5     7.742724           Home_runs
# 6     3.610228                Walk
# 7     2.327414          Strikeouts
# 8     1.764649        Stolen_Bases
# 9     5.426394  Earned_Run_Average
# 10    2.521361      Complete_Games
# 11    3.274831            Shutouts
# 12    2.111735               Saves
# 13    2.023312              Errors

# %% [markdown]
# Now, we can see that  multicollineraity has been removed between  the columns. Now we can go for model building

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
maxAcc = 0
maxRS= 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train,y_train)
    pred = LR.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRS = i
        
print("The best r2_score is ", maxAcc, "at random state ", maxRS)
# Out:
# The best r2_score is  0.9137942082029793 at random state  83

# %% [markdown]
# Train Test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %% [markdown]
# # Regression Algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

# %%
#checking accuracy for LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
pred_train_LR = LR.predict(x_train)
print('R2_score : ', r2_score(y_test,predLR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_LR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predLR))
print('Mean Squared Error : ', mean_squared_error(y_test,predLR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# R2_score :  91.37942082029792
# R2_score on training data :  92.94369999515342
# Mean Absolute Error :  2.230843487820391
# Mean Squared Error :  7.605266520759376
# Root Mean Squared Error :  2.7577647689314215

# %%
#checking accuracy for RandomForestRegressor
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR = RFR.predict(x_test)
pred_train_RFR = RFR.predict(x_train)
print('R2_score : ', r2_score(y_test,predRFR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_RFR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predRFR))
print('Mean Squared Error : ', mean_squared_error(y_test,predRFR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predRFR)))
# Out:
# R2_score :  30.386649874055426
# R2_score on training data :  93.14714241765454
# Mean Absolute Error :  6.055555555555555
# Mean Squared Error :  61.414444444444435
# Root Mean Squared Error :  7.836736849253294

# %%
#checking accuracy for ExtraTreesRegressor
ETC = ExtraTreesRegressor()
ETC.fit(x_train,y_train)
predETC = ETC.predict(x_test)
pred_train_ETC = ETC.predict(x_train)
print('R2_score : ', r2_score(y_test,predETC)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_ETC)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predETC))
print('Mean Squared Error : ', mean_squared_error(y_test,predETC))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predETC)))
# Out:
# R2_score :  43.95042821158688
# R2_score on training data :  100.0
# Mean Absolute Error :  5.680000000000002
# Mean Squared Error :  49.4481777777778
# Root Mean Squared Error :  7.031939830358178

# %%
#checking accuracy for GradientBoostingRegressor
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR = GBR.predict(x_test)
pred_train_GBR = GBR.predict(x_train)
print('R2_score : ', r2_score(y_test,predGBR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_GBR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predGBR))
print('Mean Squared Error : ', mean_squared_error(y_test,predGBR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predGBR)))
# Out:
# R2_score :  28.87010862319136
# R2_score on training data :  99.99999084623656
# Mean Absolute Error :  6.783583895045124
# Mean Squared Error :  62.752370836873396
# Root Mean Squared Error :  7.921639403360481

# %%
#checking accuracy for AdaBoostRegressor
ABR = AdaBoostRegressor()
ABR.fit(x_train,y_train)
predABR = ABR.predict(x_test)
pred_train_ABR = ABR.predict(x_train)
print('R2_score : ', r2_score(y_test,predABR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_ABR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predABR))
print('Mean Squared Error : ', mean_squared_error(y_test,predABR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predABR)))
# Out:
# R2_score :  -6.978519451441367
# R2_score on training data :  99.52954606716553
# Mean Absolute Error :  7.207407407407408
# Mean Squared Error :  94.37882716049383
# Root Mean Squared Error :  9.714876590080484

# %%
#checking accuracy for BaggingRegressor
BR = BaggingRegressor()
BR.fit(x_train,y_train)
predBR = BR.predict(x_test)
pred_train_BR = BR.predict(x_train)
print('R2_score : ', r2_score(y_test,predBR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_BR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predBR))
print('Mean Squared Error : ', mean_squared_error(y_test,predBR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predBR)))
# Out:
# R2_score :  8.41561712846348
# R2_score on training data :  93.09159522539892
# Mean Absolute Error :  7.222222222222222
# Mean Squared Error :  80.79777777777777
# Root Mean Squared Error :  8.988758411359033

# %%
#checking accuracy for DecisionTreeRegressor
DTR = DecisionTreeRegressor()
DTR.fit(x_train,y_train)
predDTR = DTR.predict(x_test)
pred_train_DTR = DTR.predict(x_train)
print('R2_score : ', r2_score(y_test,predDTR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_DTR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predDTR))
print('Mean Squared Error : ', mean_squared_error(y_test,predDTR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predDTR)))
# Out:
# R2_score :  2.518891687657432
# R2_score on training data :  100.0
# Mean Absolute Error :  6.444444444444445
# Mean Squared Error :  86.0
# Root Mean Squared Error :  9.273618495495704

# %%
#checking accuracy for KNeighborsRegressor
KNN = KNeighborsRegressor()
KNN.fit(x_train,y_train)
predKNN = KNN.predict(x_test)
pred_train_KNN = KNN.predict(x_train)
print('R2_score : ', r2_score(y_test,predKNN)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_KNN)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predKNN))
print('Mean Squared Error : ', mean_squared_error(y_test,predKNN))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predKNN)))
# Out:
# R2_score :  38.035264483627216
# R2_score on training data :  60.267197177899014
# Mean Absolute Error :  6.800000000000001
# Mean Squared Error :  54.66666666666666
# Root Mean Squared Error :  7.393691004272944

# %%
#checking accuracy for Lasso
LA = Lasso()
LA.fit(x_train,y_train)
predLA = LA.predict(x_test)
pred_train_LA = LA.predict(x_train)
print('R2_score : ', r2_score(y_test,predLA)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_LA)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predLA))
print('Mean Squared Error : ', mean_squared_error(y_test,predLA))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predLA)))
# Out:
# R2_score :  88.15599806560465
# R2_score on training data :  88.59562465751112
# Mean Absolute Error :  2.4893697752575576
# Mean Squared Error :  10.449041706566565
# Root Mean Squared Error :  3.232497750434881

# %%
#checking accuracy for Ridge
RD = Ridge()
RD.fit(x_train,y_train)
predRD = RD.predict(x_test)
pred_train_RD = RD.predict(x_train)
print('R2_score : ', r2_score(y_test,predRD)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_RD)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predRD))
print('Mean Squared Error : ', mean_squared_error(y_test,predRD))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predRD)))
# Out:
# R2_score :  84.52862680580814
# R2_score on training data :  92.43373538277511
# Mean Absolute Error :  3.1415656505910996
# Mean Squared Error :  13.64918924020926
# Root Mean Squared Error :  3.694480916205856

# %% [markdown]
# # CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
#checking CV score for LinearRegression

score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predLR) - score.mean())*100)
# Out:
# [ 0.49325998 -0.75336304  0.49231221  0.62667587  0.73032289]
# 0.31784158150745806
# Difference between R2_score score and CV score is  59.59526266955213

# %%
#checking CV score for RandomForestRegressor

score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predRFR) - score.mean())*100)
# Out:
# [ 0.25133321 -4.86304198  0.14085164  0.43969155  0.65761249]
# -0.6747106185948171
# Difference between R2_score score and CV score is  97.85771173353713

# %%
#checking CV score for ExtraTreesRegressor

score = cross_val_score(ETC,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predETC) - score.mean())*100)
# Out:
# [ 0.08521847 -3.61799389  0.3987005   0.39581074  0.7484729 ]
# -0.3979582576738938
# Difference between R2_score score and CV score is  83.74625397897626

# %%
#checking CV score for GradientBoostingRegressor

score = cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predGBR) - score.mean())*100)
# Out:
# [ 0.07955943 -6.78148999  0.22358428  0.63823926  0.4342219 ]
# -1.0811770245942476
# Difference between R2_score score and CV score is  136.9878110826161

# %%
#checking CV score for AdaBoostRegressor

score = cross_val_score(ABR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predABR) - score.mean())*100)
# Out:
# [ 0.34410985 -7.90976171  0.18926885  0.19455782  0.73780621]
# -1.2888037954986697
# Difference between R2_score score and CV score is  121.9018600984256

# %%
#checking CV score for BaggingRegressor

score = cross_val_score(BR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predBR) - score.mean())*100)
# Out:
# [ 0.21320604 -6.42351145  0.19533511  0.27059969  0.72486982]
# -1.0039001584715432
# Difference between R2_score score and CV score is  108.80563297561781

# %%
#checking CV score for DecisionTreeRegressor

score = cross_val_score(DTR,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predDTR) - score.mean())*100)
# Out:
# [-0.44937833 -8.60687023 -0.70220868  0.45368917  0.53491124]
# -1.7539713662417806
# Difference between R2_score score and CV score is  177.9160283118355

# %%
#checking CV score for KNeighborsRegressor

score = cross_val_score(KNN,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predKNN) - score.mean())*100)
# Out:
# [ 0.17619893 -2.76351145  0.10278751  0.33885086  0.53547929]
# -0.32203897064354775
# Difference between R2_score score and CV score is  70.239161547982

# %%
#checking CV score for Lasso

score = cross_val_score(LA,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predLA) - score.mean())*100)
# Out:
# [ 0.7738571  -0.22011973  0.70888262  0.7044793   0.91521454]
# 0.5764627676720782
# Difference between R2_score score and CV score is  30.50972129839683

# %%
#checking CV score for Ridge

score = cross_val_score(RD,x,y)
print(score)
print(score.mean())
print("Difference between R2_score score and CV score is ", (r2_score(y_test,predRD) - score.mean())*100)
# Out:
# [ 0.58952289 -0.79198358  0.54590419  0.75311772  0.87288371]
# 0.3938889887636634
# Difference between R2_score score and CV score is  45.13972792944181

# %% [markdown]
# As we can see that Lasso has the highest R2_score and cross_val_score and the diff bet r2 score and cv also very less.

# %% [markdown]
# # Lasso is our best model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#Using Grid Search CV on Gradient Boosting Regressor

from sklearn.model_selection import GridSearchCV

parameters = {'alpha' : [0.5, 1.0, 1.5],
              'fit_intercept' : [True, False],
              'selection' : ['cyclic', 'random'],
              'copy_X' : [True, False]}

# %%
GCV = GridSearchCV(Lasso(), parameters, cv = 5 )

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.5, 1.0, 1.5], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'selection': ['cyclic', 'random']})

# %%
Best_Parameters = GCV.best_params_
print(Best_Parameters)
# Out:
# {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'selection': 'random'}

# %% [markdown]
# Finding best random state for our best model

# %%
maxAcc = 0
maxRS= 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    LO = Lasso()
    LO.fit(x_train,y_train)
    pred = LO.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRS = i
        
print("The best r2_score is ", maxAcc, "at random state ", maxRS)
# Out:
# The best r2_score is  0.9592243133634406 at random state  97

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=97)
Final_model= Lasso(alpha = 1.0, copy_X= True, fit_intercept = True, selection = 'random')
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score : ', r2_score(y_test,pred))
print('Mean Absolute Error : ', mean_absolute_error(y_test,pred))
print('Mean Squared Error : ', mean_squared_error(y_test,pred))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score :  0.9592289923539686
# Mean Absolute Error :  1.4995116941871867
# Mean Squared Error :  3.8687156144123094
# Root Mean Squared Error :  1.9669050852576262

# %% [markdown]
# # The R2_score for our best model is 95.9%

# %% [markdown]
# # Saving the Best model

# %%
import joblib
joblib.dump(Final_model, "Baseball_Win_prediction.pkl")
# Out:
# ['Baseball_Win_prediction.pkl']

# %% [markdown]
# # Loading and Prediction

# %%
load_model= joblib.load("Baseball_Win_prediction.pkl")

# %%
prediction=pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])

# %%
prediction
# Out:
#                    0          1          2          3          4          5  \
# Predicted  86.826596  80.768882  71.923902  94.575625  64.581995  86.075506
# Original   86.000000  81.000000  71.000000  98.000000  63.000000  87.000000
#
#                    6          7         8
# Predicted  81.455777  89.930349  82.96925
# Original   83.000000  90.000000  79.00000

# %%
sns.regplot(x=y_test[:],y=load_model.predict(x_test)[:])
plt.xlabel('Actual Wins')
plt.ylabel('Predicted Wins')
# Out:
# Text(0, 0.5, 'Predicted Wins')
